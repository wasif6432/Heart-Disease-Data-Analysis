# %%
# Import necessary modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Create DataFrame and display top 10 rows
df = pd.read_csv("Heart Disease data.csv")
df.head(10)
# Out:
#    age  sex  cp  restbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0      125   212    0        1      168      0      1.0      2
# 1   53    1   0      140   203    1        0      155      1      3.1      0
# 2   70    1   0      145   174    0        1      125      1      2.6      0
# 3   61    1   0      148   203    0        1      161      0      0.0      2
# 4   62    0   0      138   294    1        1      106      0      1.9      1
# 5   58    0   0      100   248    0        0      122      0      1.0      1
# 6   58    1   0      114   318    0        2      140      0      4.4      0
# 7   55    1   0      160   289    0        0      145      1      0.8      1
# 8   46    1   0      120   249    0        0      144      0      0.8      2
# 9   54    1   0      122   286    0        0      116      1      3.2      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# ...

# %% [markdown]
# - age
# - sex
#      - 0: female
#      - 1: male
# - chest pain type (4 values)
#      - 0: typical angina
#      - 1: atypical angina
#      - 2: non-anginal pain
#      - 3: asymptomatic
# - restbps: resting blood pressure (in mm/Hg on admission to the hospital)
# - chol: serum cholesterol (in mg/dl)
# - fbs: fasting blood sugar > 120mg/dl
#      - 1: ture
#      - 0: false
# - restecg: resting electrocardiographic results
#      - 0: normal
#      - 1: having ST-T wave abnormality( T wave inversions and/or ST elevation or depression of > 0.05 mV)
#      - 2:  showing probable or definite left ventricular hypertrophy by Estes' criteria
# - thalach: maximum heart rate achieved
# - exang: exercise induced angina
#      - 1: yes
#      - 0: no
# - oldpeak: ST depression induced by exercise relative to rest
# - slope: the slope of the peak exercise ST segment
#      - 1: upsloping
#      - 2: flat
#      - 3: downsloping
# - ca: number of major vessels (0-3) coloured by flouroscopy
# - thal:
#      - 0: normal
#      - 1: fixed defect
#      - 2: reversible defect
#      - 3: reversible defect
# - target:
#      - 0: less chance of heart attack
#      - 1: more chance of heart attack

# %%
# shape of the dataset
df.shape
# Out:
# (1025, 14)

# %%
print("No. of Rows", df.shape[0])
print("No. of Columns", df.shape[1])
# Out:
# No. of Rows 1025
# No. of Columns 14

# %%
# information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   age      1025 non-null   int64
#  1   sex      1025 non-null   int64
#  2   cp       1025 non-null   int64
#  3   restbps  1025 non-null   int64
#  4   chol     1025 non-null   int64
#  5   fbs      1025 non-null   int64
#  6   restecg  1025 non-null   int64
#  7   thalach  1025 non-null   int64
#  8   exang    1025 non-null   int64
#  9   oldpeak  1025 non-null   float64
#  10  slope    1025 non-null   int64
#  11  ca       1025 non-null   int64
#  12  thal     1025 non-null   int64
#  13  target   1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
# check null value in the dataset
df.isnull().sum()
# Out:
# age        0
# sex        0
# cp         0
# restbps    0
# chol       0
# fbs        0
# restecg    0
# thalach    0
# exang      0
# oldpeak    0
# slope      0
# ca         0
# thal       0
# target     0
# dtype: int64

# %%
# check duplicate data in the dataset
df.duplicated().any()

# if it has duplicate data it will show true else false
# Out:
# np.True_

# %%
# check the shape again
df.shape
# Out:
# (1025, 14)

# %%
# now drop the duplicate data in the dataset
data = df.drop_duplicates()

# %%
# now check the shape of the new dataset (data)
data.shape
# Out:
# (302, 14)

# %%
data.to_csv('new_heart_disease_data.csv', index=False)

# %%
# overall statistics about the new dataset
data.describe()
# Out:
#              age         sex          cp     restbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# ...

# %%
# correlation matrix
data.corr()
# Out:
#               age       sex        cp   restbps      chol       fbs   restecg  \
# age      1.000000 -0.094962 -0.063107  0.283121  0.207216  0.119492 -0.111590
# sex     -0.094962  1.000000 -0.051740 -0.057647 -0.195571  0.046022 -0.060351
# cp      -0.063107 -0.051740  1.000000  0.046486 -0.072682  0.096018  0.041561
# restbps  0.283121 -0.057647  0.046486  1.000000  0.125256  0.178125 -0.115367
# chol     0.207216 -0.195571 -0.072682  0.125256  1.000000  0.011428 -0.147602
# fbs      0.119492  0.046022  0.096018  0.178125  0.011428  1.000000 -0.083081
# restecg -0.111590 -0.060351  0.041561 -0.115367 -0.147602 -0.083081  1.000000
# thalach -0.395235 -0.046439  0.293367 -0.048023 -0.005308 -0.007169  0.041210
# exang    0.093216  0.143460 -0.392937  0.068526  0.064099  0.024729 -0.068807
# oldpeak  0.206040  0.098322 -0.146692  0.194600  0.050086  0.004514 -0.056251
# slope   -0.164124 -0.032990  0.116854 -0.122873  0.000417 -0.058654  0.090402
# ...

# %%
# display correlation on a heatmap
plt.figure(figsize=(12,8))
sns.heatmap(data.corr(), annot=True)
plt.show()

# %%
# no. of people having heart disease and no. of people don't have heart disease
data['target'].value_counts()
# Out:
# target
# 1    164
# 0    138
# Name: count, dtype: int64

# %%
# plot it on a graph
sns.countplot(x="target", data=data, hue="target")
plt.xticks([0,1], ['No-Disease', 'Disease'])
plt.legend(labels=['No-Disease', 'Disease'])
plt.show()

# %%
# count of male and female in this dataset
data['sex'].value_counts()
# Out:
# sex
# 1    206
# 0     96
# Name: count, dtype: int64

# %%
# plot it on a graph
sns.countplot(x="sex", data=data, hue="sex")
plt.xticks([0,1], ['Female', 'Male'])
plt.legend(labels=['Famale', 'Male'])
plt.show()

# %%
# gender distribution according to the target
sns.countplot(x="sex", data=data, hue="target")
plt.xticks([0,1], ['Female', 'Male'])
plt.legend(labels=['No-Disease', 'Disease'])
plt.show()

# %%
# age distribution
sns.displot(data['age'], bins=20)
plt.show()

# %%
# chest pain type
sns.countplot(x="cp", data=data, hue='cp')
plt.legend(labels=['0: typical angina', '1: atypical angina', '2: non-anginal pain', '3: asymptomatic'])
plt.show()

# %%
# chest pain distribution as per the target
sns.countplot(x="cp", data=data, hue='target')
plt.legend(labels=['No-Disease', 'Disease'])
plt.show()

# %%
# fasting BPs according to target
sns.countplot(x="fbs", data=data, hue='target')
plt.legend(labels=['No-Disease', 'Disease'])
plt.show()

# %%
# resting BP distribution
data['restbps'].hist()
# Out:
# <Axes: >

# %%
# compare resting BPs as per sex
g = sns.FacetGrid(data, hue='sex', aspect=4)
g.map(sns.kdeplot, 'restbps', shade=True)
plt.legend(labels=['Famale', 'Male'])
# Out:
# C:\Users\syedw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\syedw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)

# %%
# distribution of serum cholesterol
data['chol'].hist()
# Out:
# <Axes: >

# %%
# continuous variables
categorical_var = []
continuous_var = []

for column in data.columns:
    if data[column].nunique() <= 10:
        categorical_var.append(column)
    else:
        continuous_var.append(column)

# %%
categorical_var
# Out:
# ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'target']

# %%
continuous_var
# Out:
# ['age', 'restbps', 'chol', 'thalach', 'oldpeak']

# %%
# plot it on a graph
data.hist(continuous_var, figsize=(15,8))
plt.show()
